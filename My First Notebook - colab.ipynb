# %% [markdown]
# # My First Notebook
#
# ## Learn Python with Colab
#
# **How to learn Python?**
#
#
#
# ```
# # This is formatted as code
# ```
#
# `a=5` is a equal to 5.

# %%
import numpy as np

# %%
# a is 5
a = 5
print(a)
# Out:
# 5

# %%
a
# Out:
# 5

# %% [markdown]
# ### Mathematical Operations

# %%
2*(3+4)
# Out:
# 14

# %%
print('first value:', 2)
# Out:
# first value: 2

# %%
Numbers = [4,3,2,1]
Numbers.sort()
Numbers
# Out:
# [1, 2, 3, 4]
